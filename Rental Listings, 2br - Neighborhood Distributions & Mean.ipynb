# %% [markdown]
# # Somerville 2B Rent Distribution, Davis Square vs. Union Square (Prospect Hill)

# %%
data <- read.csv("listings_joined_attributes_only.csv", stringsAsFactors=FALSE)
myvars <- names(data) %in% c("ask", "bedrooms", "HOOD_NAME") 
newdata <- data[myvars]

# number of records per neighborhood
hist(newdata[newdata$HOOD_NAME == "Prospect Hill",]$ask, xlim=c(0,4000), breaks=8, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
axis(1, at = seq(0, 4000, 500)) 
hist(newdata[newdata$HOOD_NAME == "Davis Square",]$ask, xlim=c(0,4000), breaks=8, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
axis(1, at = seq(0, 4000, 500)) 


# svg("prospect_hill.SVG", width= 10, height=10)
# hist(newdata[newdata$HOOD_NAME == "Prospect Hill",]$ask, xlim=c(0,4000), breaks=8, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
# axis(1, at = seq(0, 4000, 500)) 
# dev.off()

# svg("davis_square.SVG", width= 10, height=10)
# hist(newdata[newdata$HOOD_NAME == "Davis Square",]$ask, xlim=c(0,4000), breaks=8, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
# axis(1, at = seq(0, 4000, 500)) 
# dev.off()
# Out:
# Plot with title “Distribution of Rents for 2 Bedroom Apartments”
# pdf
#   2
# pdf
#   2
# Plot with title “Distribution of Rents for 2 Bedroom Apartments”

# %% [markdown]
# # Boston Listings, East Boston vs. Charleston

# %%
boston <- read.csv("boston_listings_joined_attributes_only.csv", stringsAsFactors=FALSE)
myvars <- names(boston) %in% c("ask", "bedrooms", "Name") 
newdata <- boston[myvars]

hist(newdata[newdata$Name == "Charlestown",]$ask, xlim=c(0,6000), breaks=10, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
axis(1, at = seq(0, 6000, 500)) 
hist(newdata[newdata$Name == "East Boston",]$ask, xlim=c(0,6000), breaks=5, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
axis(1, at = seq(0, 6000, 500)) 

# svg("charlestown.SVG", width= 10, height=10)
# hist(newdata[newdata$Name == "Charlestown",]$ask, xlim=c(0,6000), breaks=10, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
# axis(1, at = seq(0, 6000, 500)) 
# dev.off()

# svg("east_boston.SVG", width= 10, height=10)
# hist(newdata[newdata$Name == "East Boston",]$ask, xlim=c(0,6000), breaks=5, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
# axis(1, at = seq(0, 6000, 500)) 
# dev.off()
# Out:
# Plot with title “Distribution of Rents for 2 Bedroom Apartments”
# pdf
#   2
# pdf
#   2
# Plot with title “Distribution of Rents for 2 Bedroom Apartments”

# %% [markdown]
# # Boston 2BR Listings, Roxbury and Beacon Hill

# %%
hist(newdata[newdata$Name == "Roxbury",]$ask, xlim=c(0,9000), breaks=10, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
axis(1, at = seq(0, 9000, 500)) 
hist(newdata[newdata$Name == "Beacon Hill",]$ask, xlim=c(0,9000), breaks=10, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
axis(1, at = seq(0, 9000, 500)) 

# svg("roxbury.SVG", width= 10, height=10)
# hist(newdata[newdata$Name == "Roxbury",]$ask, xlim=c(0,9000), breaks=10, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
# axis(1, at = seq(0, 9000, 500)) 
# dev.off()

# svg("beacon_hill.SVG", width= 10, height=10)
# hist(newdata[newdata$Name == "Beacon Hill",]$ask, xlim=c(0,9000), breaks=10, xaxt="n", xlab="Asking Price", main="Distribution of Rents for 2 Bedroom Apartments")
# axis(1, at = seq(0, 9000, 500)) 
# dev.off()
# Out:
# Plot with title “Distribution of Rents for 2 Bedroom Apartments”
# pdf
#   2
# pdf
#   2
# Plot with title “Distribution of Rents for 2 Bedroom Apartments”

# %% [markdown]
# # Chelsea 2BR

# %%
chelsea <- read.csv("chelsea_listings.csv", stringsAsFactors=FALSE)
hist(chelsea$ask)

svg("chelsea.SVG", width= 10, height=10)
hist(chelsea$ask)
dev.off()
# Out:
# pdf
#   2
# Plot with title “Histogram of chelsea$ask”

# %% [markdown]
# # Average Rent for 2br

# %%
all_listings <- read.csv("all_listings.csv", stringsAsFactors=FALSE)
mean(all_listings$ask)
# Out:
# [1] 2471.476
